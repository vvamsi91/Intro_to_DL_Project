# %% [markdown]
# <a href="https://colab.research.google.com/github/indhu68/Intro_to_DL_Project/blob/main/GIN_Individual_Elephant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analyzing socializing pattern of Elephant using GIN model, here analyzed socialing pattern of an individual Elephant

# %%
# !pip install torch-geometric
# Out:
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.10/dist-packages (2.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (4.66.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.11.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2023.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (3.5.0)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import DataLoader, Data
from torch_geometric.nn import GINConv, Sequential
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Load and preprocess data
data = pd.read_csv('Kasungu_Telemetry_Pts_Oct23.csv', parse_dates=['Time.Stamp'])
data = data[["Index", "Tag", "Latitude", "Longitude", "Time.Stamp"]]
data['Time.Stamp'] = pd.to_datetime(data['Time.Stamp'])
data.sort_values(by=['Tag', 'Time.Stamp'], inplace=True)

# Filter data for one elephant
specific_tag = 5748  # Change the index to select a different elephant
data = data[data['Tag'] == specific_tag].copy()

# Calculate time differences in seconds
data.loc[:, 'Time_diff'] = data.groupby('Tag')['Time.Stamp'].diff().dt.total_seconds().fillna(0)

# Calculate latitude and longitude differences
data.loc[:, 'Lat_diff'] = data.groupby('Tag')['Latitude'].diff().fillna(0)
data.loc[:, 'Lon_diff'] = data.groupby('Tag')['Longitude'].diff().fillna(0)

# Handle small or zero time differences to avoid infinite speeds
data.loc[:, 'Time_diff'] = data['Time_diff'].replace(0, np.nan).fillna(method='bfill').fillna(1)

# Calculate speed in degrees per second
data.loc[:, 'Speed'] = np.sqrt(data['Lat_diff']**2 + data['Lon_diff']**2) / data['Time_diff']

# Replace infinities and NaNs with zero
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.fillna(0, inplace=True)

# Convert speed to meters per second
degree_to_meters = 111320  # meters per degree at the equator
data.loc[:, 'Speed_mps'] = data['Speed'] * degree_to_meters

# %%
# Normalize features
scaler = MinMaxScaler()
features = scaler.fit_transform(data[['Latitude', 'Longitude', 'Speed_mps']])
# Create edges for the graph using sequential indices
edges = []
indices = data.index.tolist()
for i in range(len(indices) - 1):
    edges.append([i, i + 1])

# Create graph data object
edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
x = torch.tensor(features, dtype=torch.float)
y = torch.tensor(data[['Latitude', 'Longitude', 'Speed_mps']].values, dtype=torch.float)

# %%
# Graph data object
graph_data = Data(x=x, edge_index=edge_index, y=y)
num_nodes = x.size(0)
train_indices, val_indices = train_test_split(np.arange(num_nodes), test_size=0.2, random_state=42)
train_mask = torch.zeros(num_nodes, dtype=torch.bool)
val_mask = torch.zeros(num_nodes, dtype=torch.bool)
train_mask[train_indices] = True
val_mask[val_indices] = True
graph_data.train_mask = train_mask
graph_data.val_mask = val_mask

# Create data loaders
train_loader = DataLoader([graph_data], batch_size=32, shuffle=True)
val_loader = DataLoader([graph_data], batch_size=32, shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
# Define the GIN model
class GIN(torch.nn.Module):
    def __init__(self, num_features, hidden_dim, output_dim):
        super(GIN, self).__init__()
        self.gin = Sequential('x, edge_index', [
            (GINConv(torch.nn.Linear(num_features, hidden_dim), train_eps=True), 'x, edge_index -> x'),
            torch.nn.ReLU(inplace=True),
            (GINConv(torch.nn.Linear(hidden_dim, hidden_dim), train_eps=True), 'x, edge_index -> x'),
            torch.nn.ReLU(inplace=True)
        ])
        self.regressor = torch.nn.Linear(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.gin(x, edge_index)
        x = self.regressor(x)
        return x

# Initialize the model
model = GIN(num_features=3, hidden_dim=256, output_dim=3)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.MSELoss(reduction='mean')

# %%
import torch.nn as nn

# Train and evaluate the model
def train_and_evaluate(model, train_loader, val_loader, optimizer, criterion, epochs):
    train_losses = []
    val_losses = []
    train_rmse_values = []
    val_rmse_values = []

    for epoch in range(1, epochs + 1):
        model.train()
        total_train_loss = 0
        total_train_rmse = 0

        for data in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output[data.train_mask], data.y[data.train_mask])
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item() * data.num_graphs

            # Calculate RMSE
            rmse = torch.sqrt(nn.functional.mse_loss(output[data.train_mask], data.y[data.train_mask]))
            total_train_rmse += rmse.item() * data.num_graphs

        model.eval()
        total_val_loss = 0
        total_val_rmse = 0

        with torch.no_grad():
            for data in val_loader:
                output = model(data)
                loss = criterion(output[data.val_mask], data.y[data.val_mask])
                total_val_loss += loss.item() * data.num_graphs

                # Calculate RMSE
                rmse = torch.sqrt(nn.functional.mse_loss(output[data.val_mask], data.y[data.val_mask]))
                total_val_rmse += rmse.item() * data.num_graphs

        # Average losses and RMSE over all batches
        avg_train_loss = total_train_loss / len(train_loader.dataset)
        avg_val_loss = total_val_loss / len(val_loader.dataset)
        avg_train_rmse = total_train_rmse / len(train_loader.dataset)
        avg_val_rmse = total_val_rmse / len(val_loader.dataset)

        # Record losses and RMSE values
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_rmse_values.append(avg_train_rmse)
        val_rmse_values.append(avg_val_rmse)

        print(f'Epoch {epoch}: Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Train RMSE: {avg_train_rmse:.4f}, Val RMSE: {avg_val_rmse:.4f}')

    # Plotting training and validation losses
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, epochs + 1), val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Losses')
    plt.legend()
    plt.show()

    # Plotting training and validation RMSE values
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, epochs + 1), train_rmse_values, label='Train RMSE')
    plt.plot(range(1, epochs + 1), val_rmse_values, label='Val RMSE')
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.title('Training and Validation RMSE Values')
    plt.legend()
    plt.show()

# Train and validate the model
train_and_evaluate(model, train_loader, val_loader, optimizer, criterion, 700)
# Out:
# Epoch 1: Train Loss: 417.0339, Val Loss: 285.7240, Train RMSE: 20.4214, Val RMSE: 16.9034
# Epoch 2: Train Loss: 285.5736, Val Loss: 147.1671, Train RMSE: 16.8989, Val RMSE: 12.1312
# Epoch 3: Train Loss: 146.8308, Val Loss: 30.3194, Train RMSE: 12.1174, Val RMSE: 5.5063
# Epoch 4: Train Loss: 29.8050, Val Loss: 49.5972, Train RMSE: 5.4594, Val RMSE: 7.0425
# Epoch 5: Train Loss: 49.0580, Val Loss: 101.2025, Train RMSE: 7.0041, Val RMSE: 10.0599
# Epoch 6: Train Loss: 100.7457, Val Loss: 67.8773, Train RMSE: 10.0372, Val RMSE: 8.2388
# Epoch 7: Train Loss: 67.4209, Val Loss: 24.6610, Train RMSE: 8.2110, Val RMSE: 4.9660
# Epoch 8: Train Loss: 24.1846, Val Loss: 12.1893, Train RMSE: 4.9178, Val RMSE: 3.4913
# Epoch 9: Train Loss: 11.7232, Val Loss: 23.5616, Train RMSE: 3.4239, Val RMSE: 4.8540
# Epoch 10: Train Loss: 23.1328, Val Loss: 38.9595, Train RMSE: 4.8097, Val RMSE: 6.2418
# Epoch 11: Train Loss: 38.5738, Val Loss: 46.6107, Train RMSE: 6.2108, Val RMSE: 6.8272
# Epoch 12: Train Loss: 46.2625, Val Loss: 43.3778, Train RMSE: 6.8017, Val RMSE: 6.5862
# Epoch 13: Train Loss: 43.0573, Val Loss: 31.7001, Train RMSE: 6.5618, Val RMSE: 5.6303
# Epoch 14: Train Loss: 31.4027, Val Loss: 16.9728, Train RMSE: 5.6038, Val RMSE: 4.1198
# Epoch 15: Train Loss: 16.6925, Val Loss: 6.1990, Train RMSE: 4.0856, Val RMSE: 2.4898
# Epoch 16: Train Loss: 5.9259, Val Loss: 5.2530, Train RMSE: 2.4343, Val RMSE: 2.2919
# Epoch 17: Train Loss: 4.9762, Val Loss: 13.6239, Train RMSE: 2.2308, Val RMSE: 3.6911
# Epoch 18: Train Loss: 13.3305, Val Loss: 21.7713, Train RMSE: 3.6511, Val RMSE: 4.6660
# Epoch 19: Train Loss: 21.4559, Val Loss: 21.4505, Train RMSE: 4.6320, Val RMSE: 4.6315
# Epoch 20: Train Loss: 21.1294, Val Loss: 14.0573, Train RMSE: 4.5967, Val RMSE: 3.7493
# Epoch 21: Train Loss: 13.7537, Val Loss: 6.2690, Train RMSE: 3.7086, Val RMSE: 2.5038
# Epoch 22: Train Loss: 5.9967, Val Loss: 2.7743, Train RMSE: 2.4488, Val RMSE: 1.6656
# Epoch 23: Train Loss: 2.5462, Val Loss: 3.9851, Train RMSE: 1.5957, Val RMSE: 1.9963
# Epoch 24: Train Loss: 3.8060, Val Loss: 7.1744, Train RMSE: 1.9509, Val RMSE: 2.6785
# Epoch 25: Train Loss: 7.0345, Val Loss: 9.5898, Train RMSE: 2.6523, Val RMSE: 3.0967
# Epoch 26: Train Loss: 9.4772, Val Loss: 9.6254, Train RMSE: 3.0785, Val RMSE: 3.1025
# Epoch 27: Train Loss: 9.5244, Val Loss: 7.2950, Train RMSE: 3.0862, Val RMSE: 2.7009
# Epoch 28: Train Loss: 7.1926, Val Loss: 4.1326, Train RMSE: 2.6819, Val RMSE: 2.0329
# Epoch 29: Train Loss: 4.0195, Val Loss: 2.2293, Train RMSE: 2.0049, Val RMSE: 1.4931
# Epoch 30: Train Loss: 2.0996, Val Loss: 2.7358, Train RMSE: 1.4490, Val RMSE: 1.6540
# Epoch 31: Train Loss: 2.5868, Val Loss: 4.3071, Train RMSE: 1.6084, Val RMSE: 2.0754
# Epoch 32: Train Loss: 4.1431, Val Loss: 4.6845, Train RMSE: 2.0355, Val RMSE: 2.1644
# Epoch 33: Train Loss: 4.5201, Val Loss: 3.5513, Train RMSE: 2.1261, Val RMSE: 1.8845
# Epoch 34: Train Loss: 3.4003, Val Loss: 2.2437, Train RMSE: 1.8440, Val RMSE: 1.4979
# Epoch 35: Train Loss: 2.1135, Val Loss: 1.9087, Train RMSE: 1.4538, Val RMSE: 1.3815
# Epoch 36: Train Loss: 1.8008, Val Loss: 2.4170, Train RMSE: 1.3420, Val RMSE: 1.5547
# Epoch 37: Train Loss: 2.3268, Val Loss: 3.0058, Train RMSE: 1.5254, Val RMSE: 1.7337
# Epoch 38: Train Loss: 2.9259, Val Loss: 2.9877, Train RMSE: 1.7105, Val RMSE: 1.7285
# Epoch 39: Train Loss: 2.9100, Val Loss: 2.2977, Train RMSE: 1.7059, Val RMSE: 1.5158
# Epoch 40: Train Loss: 2.2147, Val Loss: 1.4056, Train RMSE: 1.4882, Val RMSE: 1.1856
# Epoch 41: Train Loss: 1.3133, Val Loss: 0.9445, Train RMSE: 1.1460, Val RMSE: 0.9719
# Epoch 42: Train Loss: 0.8405, Val Loss: 1.2327, Train RMSE: 0.9168, Val RMSE: 1.1103
# Epoch 43: Train Loss: 1.1164, Val Loss: 1.8864, Train RMSE: 1.0566, Val RMSE: 1.3734
# Epoch 44: Train Loss: 1.7644, Val Loss: 2.0798, Train RMSE: 1.3283, Val RMSE: 1.4422
# Epoch 45: Train Loss: 1.9602, Val Loss: 1.5938, Train RMSE: 1.4001, Val RMSE: 1.2624
# Epoch 46: Train Loss: 1.4830, Val Loss: 0.9570, Train RMSE: 1.2178, Val RMSE: 0.9783
# Epoch 47: Train Loss: 0.8592, Val Loss: 0.7235, Train RMSE: 0.9269, Val RMSE: 0.8506
# Epoch 48: Train Loss: 0.6391, Val Loss: 0.9153, Train RMSE: 0.7994, Val RMSE: 0.9567
# Epoch 49: Train Loss: 0.8413, Val Loss: 1.1577, Train RMSE: 0.9172, Val RMSE: 1.0760
# Epoch 50: Train Loss: 1.0901, Val Loss: 1.1354, Train RMSE: 1.0441, Val RMSE: 1.0656
# Epoch 51: Train Loss: 1.0702, Val Loss: 0.8685, Train RMSE: 1.0345, Val RMSE: 0.9319
# Epoch 52: Train Loss: 0.8019, Val Loss: 0.6337, Train RMSE: 0.8955, Val RMSE: 0.7961
# Epoch 53: Train Loss: 0.5634, Val Loss: 0.6465, Train RMSE: 0.7506, Val RMSE: 0.8041
# Epoch 54: Train Loss: 0.5719, Val Loss: 0.8021, Train RMSE: 0.7562, Val RMSE: 0.8956
# Epoch 55: Train Loss: 0.7248, Val Loss: 0.8083, Train RMSE: 0.8514, Val RMSE: 0.8991
# Epoch 56: Train Loss: 0.7317, Val Loss: 0.5992, Train RMSE: 0.8554, Val RMSE: 0.7741
# Epoch 57: Train Loss: 0.5265, Val Loss: 0.4056, Train RMSE: 0.7256, Val RMSE: 0.6369
# Epoch 58: Train Loss: 0.3390, Val Loss: 0.4079, Train RMSE: 0.5823, Val RMSE: 0.6387
# Epoch 59: Train Loss: 0.3481, Val Loss: 0.5265, Train RMSE: 0.5900, Val RMSE: 0.7256
# Epoch 60: Train Loss: 0.4723, Val Loss: 0.5688, Train RMSE: 0.6872, Val RMSE: 0.7542
# Epoch 61: Train Loss: 0.5178, Val Loss: 0.4639, Train RMSE: 0.7196, Val RMSE: 0.6811
# Epoch 62: Train Loss: 0.4133, Val Loss: 0.3206, Train RMSE: 0.6429, Val RMSE: 0.5663
# Epoch 63: Train Loss: 0.2683, Val Loss: 0.2810, Train RMSE: 0.5179, Val RMSE: 0.5301
# Epoch 64: Train Loss: 0.2265, Val Loss: 0.3407, Train RMSE: 0.4759, Val RMSE: 0.5837
# Epoch 65: Train Loss: 0.2850, Val Loss: 0.3671, Train RMSE: 0.5339, Val RMSE: 0.6059
# Epoch 66: Train Loss: 0.3119, Val Loss: 0.3016, Train RMSE: 0.5585, Val RMSE: 0.5492
# Epoch 67: Train Loss: 0.2486, Val Loss: 0.2327, Train RMSE: 0.4986, Val RMSE: 0.4824
# Epoch 68: Train Loss: 0.1830, Val Loss: 0.2387, Train RMSE: 0.4277, Val RMSE: 0.4886
# Epoch 69: Train Loss: 0.1924, Val Loss: 0.2738, Train RMSE: 0.4387, Val RMSE: 0.5233
# Epoch 70: Train Loss: 0.2300, Val Loss: 0.2551, Train RMSE: 0.4796, Val RMSE: 0.5050
# Epoch 71: Train Loss: 0.2121, Val Loss: 0.1897, Train RMSE: 0.4605, Val RMSE: 0.4355
# Epoch 72: Train Loss: 0.1461, Val Loss: 0.1577, Train RMSE: 0.3823, Val RMSE: 0.3972
# Epoch 73: Train Loss: 0.1132, Val Loss: 0.1875, Train RMSE: 0.3365, Val RMSE: 0.4331
# Epoch 74: Train Loss: 0.1425, Val Loss: 0.2137, Train RMSE: 0.3774, Val RMSE: 0.4622
# Epoch 75: Train Loss: 0.1688, Val Loss: 0.1862, Train RMSE: 0.4108, Val RMSE: 0.4316
# Epoch 76: Train Loss: 0.1424, Val Loss: 0.1459, Train RMSE: 0.3773, Val RMSE: 0.3820
# Epoch 77: Train Loss: 0.1037, Val Loss: 0.1436, Train RMSE: 0.3220, Val RMSE: 0.3789
# Epoch 78: Train Loss: 0.1028, Val Loss: 0.1595, Train RMSE: 0.3206, Val RMSE: 0.3993
# Epoch 79: Train Loss: 0.1196, Val Loss: 0.1506, Train RMSE: 0.3458, Val RMSE: 0.3881
# Epoch 80: Train Loss: 0.1110, Val Loss: 0.1249, Train RMSE: 0.3331, Val RMSE: 0.3535
# Epoch 81: Train Loss: 0.0851, Val Loss: 0.1210, Train RMSE: 0.2917, Val RMSE: 0.3478
# Epoch 82: Train Loss: 0.0809, Val Loss: 0.1374, Train RMSE: 0.2844, Val RMSE: 0.3706
# Epoch 83: Train Loss: 0.0972, Val Loss: 0.1374, Train RMSE: 0.3118, Val RMSE: 0.3706
# Epoch 84: Train Loss: 0.0975, Val Loss: 0.1160, Train RMSE: 0.3122, Val RMSE: 0.3406
# Epoch 85: Train Loss: 0.0766, Val Loss: 0.1044, Train RMSE: 0.2768, Val RMSE: 0.3232
# Epoch 86: Train Loss: 0.0655, Val Loss: 0.1114, Train RMSE: 0.2560, Val RMSE: 0.3338
# Epoch 87: Train Loss: 0.0728, Val Loss: 0.1143, Train RMSE: 0.2698, Val RMSE: 0.3381
# Epoch 88: Train Loss: 0.0758, Val Loss: 0.1044, Train RMSE: 0.2753, Val RMSE: 0.3231
# Epoch 89: Train Loss: 0.0658, Val Loss: 0.0975, Train RMSE: 0.2564, Val RMSE: 0.3123
# Epoch 90: Train Loss: 0.0586, Val Loss: 0.1013, Train RMSE: 0.2422, Val RMSE: 0.3183
# Epoch 91: Train Loss: 0.0622, Val Loss: 0.1025, Train RMSE: 0.2494, Val RMSE: 0.3201
# Epoch 92: Train Loss: 0.0633, Val Loss: 0.0941, Train RMSE: 0.2516, Val RMSE: 0.3067
# Epoch 93: Train Loss: 0.0551, Val Loss: 0.0876, Train RMSE: 0.2348, Val RMSE: 0.2960
# Epoch 94: Train Loss: 0.0490, Val Loss: 0.0898, Train RMSE: 0.2213, Val RMSE: 0.2997
# Epoch 95: Train Loss: 0.0515, Val Loss: 0.0918, Train RMSE: 0.2269, Val RMSE: 0.3030
# Epoch 96: Train Loss: 0.0535, Val Loss: 0.0871, Train RMSE: 0.2314, Val RMSE: 0.2952
# Epoch 97: Train Loss: 0.0488, Val Loss: 0.0822, Train RMSE: 0.2208, Val RMSE: 0.2867
# Epoch 98: Train Loss: 0.0438, Val Loss: 0.0823, Train RMSE: 0.2093, Val RMSE: 0.2869
# Epoch 99: Train Loss: 0.0440, Val Loss: 0.0822, Train RMSE: 0.2096, Val RMSE: 0.2868
# Epoch 100: Train Loss: 0.0441, Val Loss: 0.0784, Train RMSE: 0.2100, Val RMSE: 0.2799
# Epoch 101: Train Loss: 0.0405, Val Loss: 0.0756, Train RMSE: 0.2012, Val RMSE: 0.2749
# Epoch 102: Train Loss: 0.0379, Val Loss: 0.0766, Train RMSE: 0.1947, Val RMSE: 0.2768
# Epoch 103: Train Loss: 0.0390, Val Loss: 0.0766, Train RMSE: 0.1975, Val RMSE: 0.2767
# Epoch 104: Train Loss: 0.0390, Val Loss: 0.0733, Train RMSE: 0.1974, Val RMSE: 0.2707
# Epoch 105: Train Loss: 0.0356, Val Loss: 0.0711, Train RMSE: 0.1888, Val RMSE: 0.2666
# Epoch 106: Train Loss: 0.0334, Val Loss: 0.0714, Train RMSE: 0.1827, Val RMSE: 0.2673
# Epoch 107: Train Loss: 0.0337, Val Loss: 0.0709, Train RMSE: 0.1837, Val RMSE: 0.2662
# Epoch 108: Train Loss: 0.0332, Val Loss: 0.0687, Train RMSE: 0.1822, Val RMSE: 0.2621
# Epoch 109: Train Loss: 0.0310, Val Loss: 0.0677, Train RMSE: 0.1762, Val RMSE: 0.2602
# Epoch 110: Train Loss: 0.0301, Val Loss: 0.0679, Train RMSE: 0.1735, Val RMSE: 0.2605
# Epoch 111: Train Loss: 0.0303, Val Loss: 0.0667, Train RMSE: 0.1740, Val RMSE: 0.2583
# Epoch 112: Train Loss: 0.0291, Val Loss: 0.0648, Train RMSE: 0.1707, Val RMSE: 0.2545
# Epoch 113: Train Loss: 0.0272, Val Loss: 0.0642, Train RMSE: 0.1649, Val RMSE: 0.2533
# Epoch 114: Train Loss: 0.0266, Val Loss: 0.0641, Train RMSE: 0.1632, Val RMSE: 0.2532
# Epoch 115: Train Loss: 0.0266, Val Loss: 0.0629, Train RMSE: 0.1631, Val RMSE: 0.2508
# Epoch 116: Train Loss: 0.0255, Val Loss: 0.0616, Train RMSE: 0.1597, Val RMSE: 0.2482
# Epoch 117: Train Loss: 0.0243, Val Loss: 0.0612, Train RMSE: 0.1559, Val RMSE: 0.2474
# Epoch 118: Train Loss: 0.0240, Val Loss: 0.0606, Train RMSE: 0.1549, Val RMSE: 0.2463
# Epoch 119: Train Loss: 0.0235, Val Loss: 0.0594, Train RMSE: 0.1531, Val RMSE: 0.2438
# Epoch 120: Train Loss: 0.0222, Val Loss: 0.0587, Train RMSE: 0.1490, Val RMSE: 0.2424
# Epoch 121: Train Loss: 0.0215, Val Loss: 0.0585, Train RMSE: 0.1466, Val RMSE: 0.2419
# Epoch 122: Train Loss: 0.0212, Val Loss: 0.0577, Train RMSE: 0.1457, Val RMSE: 0.2401
# Epoch 123: Train Loss: 0.0204, Val Loss: 0.0566, Train RMSE: 0.1428, Val RMSE: 0.2379
# Epoch 124: Train Loss: 0.0194, Val Loss: 0.0561, Train RMSE: 0.1391, Val RMSE: 0.2369
# Epoch 125: Train Loss: 0.0189, Val Loss: 0.0557, Train RMSE: 0.1374, Val RMSE: 0.2361
# Epoch 126: Train Loss: 0.0185, Val Loss: 0.0550, Train RMSE: 0.1358, Val RMSE: 0.2345
# Epoch 127: Train Loss: 0.0177, Val Loss: 0.0545, Train RMSE: 0.1329, Val RMSE: 0.2334
# Epoch 128: Train Loss: 0.0171, Val Loss: 0.0543, Train RMSE: 0.1309, Val RMSE: 0.2329
# Epoch 129: Train Loss: 0.0169, Val Loss: 0.0538, Train RMSE: 0.1301, Val RMSE: 0.2321
# Epoch 130: Train Loss: 0.0165, Val Loss: 0.0535, Train RMSE: 0.1283, Val RMSE: 0.2312
# Epoch 131: Train Loss: 0.0160, Val Loss: 0.0531, Train RMSE: 0.1267, Val RMSE: 0.2305
# Epoch 132: Train Loss: 0.0157, Val Loss: 0.0525, Train RMSE: 0.1254, Val RMSE: 0.2292
# Epoch 133: Train Loss: 0.0151, Val Loss: 0.0520, Train RMSE: 0.1230, Val RMSE: 0.2280
# Epoch 134: Train Loss: 0.0146, Val Loss: 0.0517, Train RMSE: 0.1209, Val RMSE: 0.2273
# Epoch 135: Train Loss: 0.0143, Val Loss: 0.0513, Train RMSE: 0.1197, Val RMSE: 0.2265
# Epoch 136: Train Loss: 0.0140, Val Loss: 0.0510, Train RMSE: 0.1184, Val RMSE: 0.2259
# Epoch 137: Train Loss: 0.0137, Val Loss: 0.0508, Train RMSE: 0.1173, Val RMSE: 0.2255
# Epoch 138: Train Loss: 0.0136, Val Loss: 0.0506, Train RMSE: 0.1165, Val RMSE: 0.2248
# Epoch 139: Train Loss: 0.0133, Val Loss: 0.0502, Train RMSE: 0.1153, Val RMSE: 0.2242
# Epoch 140: Train Loss: 0.0130, Val Loss: 0.0500, Train RMSE: 0.1139, Val RMSE: 0.2236
# Epoch 141: Train Loss: 0.0127, Val Loss: 0.0498, Train RMSE: 0.1128, Val RMSE: 0.2232
# Epoch 142: Train Loss: 0.0125, Val Loss: 0.0497, Train RMSE: 0.1119, Val RMSE: 0.2229
# Epoch 143: Train Loss: 0.0124, Val Loss: 0.0496, Train RMSE: 0.1112, Val RMSE: 0.2227
# Epoch 144: Train Loss: 0.0123, Val Loss: 0.0494, Train RMSE: 0.1107, Val RMSE: 0.2224
# Epoch 145: Train Loss: 0.0121, Val Loss: 0.0493, Train RMSE: 0.1098, Val RMSE: 0.2220
# Epoch 146: Train Loss: 0.0119, Val Loss: 0.0491, Train RMSE: 0.1090, Val RMSE: 0.2216
# Epoch 147: Train Loss: 0.0117, Val Loss: 0.0489, Train RMSE: 0.1083, Val RMSE: 0.2212
# Epoch 148: Train Loss: 0.0116, Val Loss: 0.0488, Train RMSE: 0.1075, Val RMSE: 0.2209
# Epoch 149: Train Loss: 0.0115, Val Loss: 0.0487, Train RMSE: 0.1071, Val RMSE: 0.2207
# Epoch 150: Train Loss: 0.0114, Val Loss: 0.0486, Train RMSE: 0.1066, Val RMSE: 0.2205
# Epoch 151: Train Loss: 0.0112, Val Loss: 0.0485, Train RMSE: 0.1060, Val RMSE: 0.2203
# Epoch 152: Train Loss: 0.0111, Val Loss: 0.0484, Train RMSE: 0.1054, Val RMSE: 0.2200
# Epoch 153: Train Loss: 0.0110, Val Loss: 0.0483, Train RMSE: 0.1049, Val RMSE: 0.2197
# Epoch 154: Train Loss: 0.0109, Val Loss: 0.0482, Train RMSE: 0.1043, Val RMSE: 0.2196
# Epoch 155: Train Loss: 0.0108, Val Loss: 0.0481, Train RMSE: 0.1039, Val RMSE: 0.2194
# Epoch 156: Train Loss: 0.0107, Val Loss: 0.0481, Train RMSE: 0.1034, Val RMSE: 0.2192
# Epoch 157: Train Loss: 0.0106, Val Loss: 0.0480, Train RMSE: 0.1029, Val RMSE: 0.2190
# Epoch 158: Train Loss: 0.0105, Val Loss: 0.0479, Train RMSE: 0.1025, Val RMSE: 0.2188
# Epoch 159: Train Loss: 0.0104, Val Loss: 0.0478, Train RMSE: 0.1020, Val RMSE: 0.2186
# Epoch 160: Train Loss: 0.0103, Val Loss: 0.0477, Train RMSE: 0.1016, Val RMSE: 0.2184
# Epoch 161: Train Loss: 0.0102, Val Loss: 0.0476, Train RMSE: 0.1012, Val RMSE: 0.2182
# Epoch 162: Train Loss: 0.0101, Val Loss: 0.0476, Train RMSE: 0.1007, Val RMSE: 0.2181
# Epoch 163: Train Loss: 0.0101, Val Loss: 0.0475, Train RMSE: 0.1003, Val RMSE: 0.2179
# Epoch 164: Train Loss: 0.0100, Val Loss: 0.0474, Train RMSE: 0.1000, Val RMSE: 0.2178
# Epoch 165: Train Loss: 0.0099, Val Loss: 0.0473, Train RMSE: 0.0995, Val RMSE: 0.2176
# Epoch 166: Train Loss: 0.0098, Val Loss: 0.0473, Train RMSE: 0.0992, Val RMSE: 0.2174
# Epoch 167: Train Loss: 0.0098, Val Loss: 0.0472, Train RMSE: 0.0988, Val RMSE: 0.2173
# Epoch 168: Train Loss: 0.0097, Val Loss: 0.0471, Train RMSE: 0.0984, Val RMSE: 0.2171
# Epoch 169: Train Loss: 0.0096, Val Loss: 0.0471, Train RMSE: 0.0981, Val RMSE: 0.2170
# Epoch 170: Train Loss: 0.0096, Val Loss: 0.0470, Train RMSE: 0.0978, Val RMSE: 0.2169
# Epoch 171: Train Loss: 0.0095, Val Loss: 0.0470, Train RMSE: 0.0974, Val RMSE: 0.2167
# Epoch 172: Train Loss: 0.0094, Val Loss: 0.0469, Train RMSE: 0.0971, Val RMSE: 0.2166
# Epoch 173: Train Loss: 0.0094, Val Loss: 0.0469, Train RMSE: 0.0968, Val RMSE: 0.2165
# Epoch 174: Train Loss: 0.0093, Val Loss: 0.0468, Train RMSE: 0.0965, Val RMSE: 0.2164
# Epoch 175: Train Loss: 0.0093, Val Loss: 0.0468, Train RMSE: 0.0962, Val RMSE: 0.2163
# Epoch 176: Train Loss: 0.0092, Val Loss: 0.0468, Train RMSE: 0.0959, Val RMSE: 0.2162
# Epoch 177: Train Loss: 0.0091, Val Loss: 0.0467, Train RMSE: 0.0957, Val RMSE: 0.2161
# Epoch 178: Train Loss: 0.0091, Val Loss: 0.0467, Train RMSE: 0.0954, Val RMSE: 0.2161
# Epoch 179: Train Loss: 0.0090, Val Loss: 0.0466, Train RMSE: 0.0951, Val RMSE: 0.2160
# Epoch 180: Train Loss: 0.0090, Val Loss: 0.0466, Train RMSE: 0.0948, Val RMSE: 0.2159
# Epoch 181: Train Loss: 0.0089, Val Loss: 0.0466, Train RMSE: 0.0946, Val RMSE: 0.2158
# Epoch 182: Train Loss: 0.0089, Val Loss: 0.0465, Train RMSE: 0.0943, Val RMSE: 0.2157
# Epoch 183: Train Loss: 0.0089, Val Loss: 0.0465, Train RMSE: 0.0941, Val RMSE: 0.2157
# Epoch 184: Train Loss: 0.0088, Val Loss: 0.0465, Train RMSE: 0.0939, Val RMSE: 0.2156
# Epoch 185: Train Loss: 0.0088, Val Loss: 0.0465, Train RMSE: 0.0936, Val RMSE: 0.2155
# Epoch 186: Train Loss: 0.0087, Val Loss: 0.0464, Train RMSE: 0.0934, Val RMSE: 0.2155
# Epoch 187: Train Loss: 0.0087, Val Loss: 0.0464, Train RMSE: 0.0932, Val RMSE: 0.2154
# Epoch 188: Train Loss: 0.0086, Val Loss: 0.0464, Train RMSE: 0.0929, Val RMSE: 0.2154
# Epoch 189: Train Loss: 0.0086, Val Loss: 0.0463, Train RMSE: 0.0927, Val RMSE: 0.2153
# Epoch 190: Train Loss: 0.0086, Val Loss: 0.0463, Train RMSE: 0.0925, Val RMSE: 0.2152
# Epoch 191: Train Loss: 0.0085, Val Loss: 0.0463, Train RMSE: 0.0923, Val RMSE: 0.2152
# Epoch 192: Train Loss: 0.0085, Val Loss: 0.0463, Train RMSE: 0.0921, Val RMSE: 0.2151
# Epoch 193: Train Loss: 0.0084, Val Loss: 0.0462, Train RMSE: 0.0919, Val RMSE: 0.2150
# Epoch 194: Train Loss: 0.0084, Val Loss: 0.0462, Train RMSE: 0.0917, Val RMSE: 0.2150
# Epoch 195: Train Loss: 0.0084, Val Loss: 0.0462, Train RMSE: 0.0915, Val RMSE: 0.2149
# Epoch 196: Train Loss: 0.0083, Val Loss: 0.0462, Train RMSE: 0.0913, Val RMSE: 0.2149
# Epoch 197: Train Loss: 0.0083, Val Loss: 0.0461, Train RMSE: 0.0911, Val RMSE: 0.2148
# Epoch 198: Train Loss: 0.0083, Val Loss: 0.0461, Train RMSE: 0.0909, Val RMSE: 0.2147
# Epoch 199: Train Loss: 0.0082, Val Loss: 0.0461, Train RMSE: 0.0907, Val RMSE: 0.2147
# Epoch 200: Train Loss: 0.0082, Val Loss: 0.0461, Train RMSE: 0.0905, Val RMSE: 0.2146
# Epoch 201: Train Loss: 0.0082, Val Loss: 0.0460, Train RMSE: 0.0903, Val RMSE: 0.2146
# Epoch 202: Train Loss: 0.0081, Val Loss: 0.0460, Train RMSE: 0.0902, Val RMSE: 0.2145
# Epoch 203: Train Loss: 0.0081, Val Loss: 0.0460, Train RMSE: 0.0900, Val RMSE: 0.2145
# Epoch 204: Train Loss: 0.0081, Val Loss: 0.0460, Train RMSE: 0.0898, Val RMSE: 0.2144
# Epoch 205: Train Loss: 0.0080, Val Loss: 0.0460, Train RMSE: 0.0896, Val RMSE: 0.2144
# Epoch 206: Train Loss: 0.0080, Val Loss: 0.0459, Train RMSE: 0.0895, Val RMSE: 0.2143
# Epoch 207: Train Loss: 0.0080, Val Loss: 0.0459, Train RMSE: 0.0893, Val RMSE: 0.2143
# Epoch 208: Train Loss: 0.0079, Val Loss: 0.0459, Train RMSE: 0.0891, Val RMSE: 0.2142
# Epoch 209: Train Loss: 0.0079, Val Loss: 0.0459, Train RMSE: 0.0890, Val RMSE: 0.2142
# Epoch 210: Train Loss: 0.0079, Val Loss: 0.0459, Train RMSE: 0.0888, Val RMSE: 0.2141
# Epoch 211: Train Loss: 0.0079, Val Loss: 0.0458, Train RMSE: 0.0887, Val RMSE: 0.2141
# Epoch 212: Train Loss: 0.0078, Val Loss: 0.0458, Train RMSE: 0.0885, Val RMSE: 0.2141
# Epoch 213: Train Loss: 0.0078, Val Loss: 0.0458, Train RMSE: 0.0884, Val RMSE: 0.2140
# Epoch 214: Train Loss: 0.0078, Val Loss: 0.0458, Train RMSE: 0.0882, Val RMSE: 0.2140
# Epoch 215: Train Loss: 0.0078, Val Loss: 0.0458, Train RMSE: 0.0881, Val RMSE: 0.2139
# Epoch 216: Train Loss: 0.0077, Val Loss: 0.0457, Train RMSE: 0.0879, Val RMSE: 0.2139
# Epoch 217: Train Loss: 0.0077, Val Loss: 0.0457, Train RMSE: 0.0878, Val RMSE: 0.2138
# Epoch 218: Train Loss: 0.0077, Val Loss: 0.0457, Train RMSE: 0.0876, Val RMSE: 0.2138
# Epoch 219: Train Loss: 0.0077, Val Loss: 0.0457, Train RMSE: 0.0875, Val RMSE: 0.2138
# Epoch 220: Train Loss: 0.0076, Val Loss: 0.0457, Train RMSE: 0.0873, Val RMSE: 0.2137
# Epoch 221: Train Loss: 0.0076, Val Loss: 0.0457, Train RMSE: 0.0872, Val RMSE: 0.2137
# Epoch 222: Train Loss: 0.0076, Val Loss: 0.0456, Train RMSE: 0.0871, Val RMSE: 0.2136
# Epoch 223: Train Loss: 0.0076, Val Loss: 0.0456, Train RMSE: 0.0869, Val RMSE: 0.2136
# Epoch 224: Train Loss: 0.0075, Val Loss: 0.0456, Train RMSE: 0.0868, Val RMSE: 0.2136
# Epoch 225: Train Loss: 0.0075, Val Loss: 0.0456, Train RMSE: 0.0867, Val RMSE: 0.2135
# Epoch 226: Train Loss: 0.0075, Val Loss: 0.0456, Train RMSE: 0.0865, Val RMSE: 0.2135
# Epoch 227: Train Loss: 0.0075, Val Loss: 0.0456, Train RMSE: 0.0864, Val RMSE: 0.2135
# Epoch 228: Train Loss: 0.0074, Val Loss: 0.0456, Train RMSE: 0.0863, Val RMSE: 0.2134
# Epoch 229: Train Loss: 0.0074, Val Loss: 0.0455, Train RMSE: 0.0862, Val RMSE: 0.2134
# Epoch 230: Train Loss: 0.0074, Val Loss: 0.0455, Train RMSE: 0.0860, Val RMSE: 0.2134
# Epoch 231: Train Loss: 0.0074, Val Loss: 0.0455, Train RMSE: 0.0859, Val RMSE: 0.2133
# Epoch 232: Train Loss: 0.0074, Val Loss: 0.0455, Train RMSE: 0.0858, Val RMSE: 0.2133
# Epoch 233: Train Loss: 0.0073, Val Loss: 0.0455, Train RMSE: 0.0857, Val RMSE: 0.2133
# Epoch 234: Train Loss: 0.0073, Val Loss: 0.0455, Train RMSE: 0.0855, Val RMSE: 0.2132
# Epoch 235: Train Loss: 0.0073, Val Loss: 0.0454, Train RMSE: 0.0854, Val RMSE: 0.2132
# Epoch 236: Train Loss: 0.0073, Val Loss: 0.0454, Train RMSE: 0.0853, Val RMSE: 0.2132
# Epoch 237: Train Loss: 0.0073, Val Loss: 0.0454, Train RMSE: 0.0852, Val RMSE: 0.2131
# Epoch 238: Train Loss: 0.0072, Val Loss: 0.0454, Train RMSE: 0.0851, Val RMSE: 0.2131
# Epoch 239: Train Loss: 0.0072, Val Loss: 0.0454, Train RMSE: 0.0850, Val RMSE: 0.2131
# Epoch 240: Train Loss: 0.0072, Val Loss: 0.0454, Train RMSE: 0.0849, Val RMSE: 0.2130
# Epoch 241: Train Loss: 0.0072, Val Loss: 0.0454, Train RMSE: 0.0848, Val RMSE: 0.2130
# Epoch 242: Train Loss: 0.0072, Val Loss: 0.0454, Train RMSE: 0.0847, Val RMSE: 0.2130
# Epoch 243: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0845, Val RMSE: 0.2129
# Epoch 244: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0844, Val RMSE: 0.2129
# Epoch 245: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0843, Val RMSE: 0.2129
# Epoch 246: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0842, Val RMSE: 0.2128
# Epoch 247: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0841, Val RMSE: 0.2128
# Epoch 248: Train Loss: 0.0071, Val Loss: 0.0453, Train RMSE: 0.0840, Val RMSE: 0.2128
# Epoch 249: Train Loss: 0.0070, Val Loss: 0.0453, Train RMSE: 0.0839, Val RMSE: 0.2128
# Epoch 250: Train Loss: 0.0070, Val Loss: 0.0453, Train RMSE: 0.0838, Val RMSE: 0.2127
# Epoch 251: Train Loss: 0.0070, Val Loss: 0.0452, Train RMSE: 0.0837, Val RMSE: 0.2127
# Epoch 252: Train Loss: 0.0070, Val Loss: 0.0452, Train RMSE: 0.0837, Val RMSE: 0.2127
# Epoch 253: Train Loss: 0.0070, Val Loss: 0.0452, Train RMSE: 0.0836, Val RMSE: 0.2126
# Epoch 254: Train Loss: 0.0070, Val Loss: 0.0452, Train RMSE: 0.0835, Val RMSE: 0.2126
# Epoch 255: Train Loss: 0.0070, Val Loss: 0.0452, Train RMSE: 0.0834, Val RMSE: 0.2126
# Epoch 256: Train Loss: 0.0069, Val Loss: 0.0452, Train RMSE: 0.0833, Val RMSE: 0.2126
# Epoch 257: Train Loss: 0.0069, Val Loss: 0.0452, Train RMSE: 0.0832, Val RMSE: 0.2125
# Epoch 258: Train Loss: 0.0069, Val Loss: 0.0452, Train RMSE: 0.0831, Val RMSE: 0.2125
# Epoch 259: Train Loss: 0.0069, Val Loss: 0.0451, Train RMSE: 0.0830, Val RMSE: 0.2125
# Epoch 260: Train Loss: 0.0069, Val Loss: 0.0451, Train RMSE: 0.0829, Val RMSE: 0.2124
# Epoch 261: Train Loss: 0.0069, Val Loss: 0.0451, Train RMSE: 0.0828, Val RMSE: 0.2124
# Epoch 262: Train Loss: 0.0068, Val Loss: 0.0451, Train RMSE: 0.0827, Val RMSE: 0.2124
# Epoch 263: Train Loss: 0.0068, Val Loss: 0.0451, Train RMSE: 0.0827, Val RMSE: 0.2124
# Epoch 264: Train Loss: 0.0068, Val Loss: 0.0451, Train RMSE: 0.0826, Val RMSE: 0.2123
# Epoch 265: Train Loss: 0.0068, Val Loss: 0.0451, Train RMSE: 0.0825, Val RMSE: 0.2123
# Epoch 266: Train Loss: 0.0068, Val Loss: 0.0451, Train RMSE: 0.0824, Val RMSE: 0.2123
# Epoch 267: Train Loss: 0.0068, Val Loss: 0.0450, Train RMSE: 0.0823, Val RMSE: 0.2122
# Epoch 268: Train Loss: 0.0068, Val Loss: 0.0450, Train RMSE: 0.0822, Val RMSE: 0.2122
# Epoch 269: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0822, Val RMSE: 0.2122
# Epoch 270: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0821, Val RMSE: 0.2122
# Epoch 271: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0820, Val RMSE: 0.2121
# Epoch 272: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0819, Val RMSE: 0.2121
# Epoch 273: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0818, Val RMSE: 0.2121
# Epoch 274: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0817, Val RMSE: 0.2120
# Epoch 275: Train Loss: 0.0067, Val Loss: 0.0450, Train RMSE: 0.0817, Val RMSE: 0.2120
# Epoch 276: Train Loss: 0.0067, Val Loss: 0.0449, Train RMSE: 0.0816, Val RMSE: 0.2120
# Epoch 277: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0815, Val RMSE: 0.2120
# Epoch 278: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0814, Val RMSE: 0.2119
# Epoch 279: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0814, Val RMSE: 0.2119
# Epoch 280: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0813, Val RMSE: 0.2119
# Epoch 281: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0812, Val RMSE: 0.2119
# Epoch 282: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0811, Val RMSE: 0.2118
# Epoch 283: Train Loss: 0.0066, Val Loss: 0.0449, Train RMSE: 0.0811, Val RMSE: 0.2118
# Epoch 284: Train Loss: 0.0066, Val Loss: 0.0448, Train RMSE: 0.0810, Val RMSE: 0.2118
# Epoch 285: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0809, Val RMSE: 0.2117
# Epoch 286: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0808, Val RMSE: 0.2117
# Epoch 287: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0808, Val RMSE: 0.2117
# Epoch 288: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0807, Val RMSE: 0.2117
# Epoch 289: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0806, Val RMSE: 0.2116
# Epoch 290: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0806, Val RMSE: 0.2116
# Epoch 291: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0805, Val RMSE: 0.2116
# Epoch 292: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0804, Val RMSE: 0.2116
# Epoch 293: Train Loss: 0.0065, Val Loss: 0.0448, Train RMSE: 0.0804, Val RMSE: 0.2116
# Epoch 294: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0803, Val RMSE: 0.2115
# Epoch 295: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0802, Val RMSE: 0.2115
# Epoch 296: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0802, Val RMSE: 0.2115
# Epoch 297: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0801, Val RMSE: 0.2115
# Epoch 298: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0800, Val RMSE: 0.2115
# Epoch 299: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0800, Val RMSE: 0.2114
# Epoch 300: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0799, Val RMSE: 0.2114
# Epoch 301: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0798, Val RMSE: 0.2114
# Epoch 302: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0798, Val RMSE: 0.2114
# Epoch 303: Train Loss: 0.0064, Val Loss: 0.0447, Train RMSE: 0.0797, Val RMSE: 0.2113
# Epoch 304: Train Loss: 0.0063, Val Loss: 0.0447, Train RMSE: 0.0797, Val RMSE: 0.2113
# Epoch 305: Train Loss: 0.0063, Val Loss: 0.0447, Train RMSE: 0.0796, Val RMSE: 0.2113
# Epoch 306: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0795, Val RMSE: 0.2113
# Epoch 307: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0795, Val RMSE: 0.2113
# Epoch 308: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0794, Val RMSE: 0.2113
# Epoch 309: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0794, Val RMSE: 0.2112
# Epoch 310: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0793, Val RMSE: 0.2112
# Epoch 311: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0793, Val RMSE: 0.2112
# Epoch 312: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0792, Val RMSE: 0.2112
# Epoch 313: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0791, Val RMSE: 0.2112
# Epoch 314: Train Loss: 0.0063, Val Loss: 0.0446, Train RMSE: 0.0791, Val RMSE: 0.2111
# Epoch 315: Train Loss: 0.0062, Val Loss: 0.0446, Train RMSE: 0.0790, Val RMSE: 0.2111
# Epoch 316: Train Loss: 0.0062, Val Loss: 0.0446, Train RMSE: 0.0790, Val RMSE: 0.2111
# Epoch 317: Train Loss: 0.0062, Val Loss: 0.0446, Train RMSE: 0.0789, Val RMSE: 0.2111
# Epoch 318: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0789, Val RMSE: 0.2111
# Epoch 319: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0788, Val RMSE: 0.2110
# Epoch 320: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0788, Val RMSE: 0.2110
# Epoch 321: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0787, Val RMSE: 0.2110
# Epoch 322: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0787, Val RMSE: 0.2110
# Epoch 323: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0786, Val RMSE: 0.2110
# Epoch 324: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0786, Val RMSE: 0.2110
# Epoch 325: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0785, Val RMSE: 0.2109
# Epoch 326: Train Loss: 0.0062, Val Loss: 0.0445, Train RMSE: 0.0785, Val RMSE: 0.2109
# Epoch 327: Train Loss: 0.0061, Val Loss: 0.0445, Train RMSE: 0.0784, Val RMSE: 0.2109
# Epoch 328: Train Loss: 0.0061, Val Loss: 0.0445, Train RMSE: 0.0784, Val RMSE: 0.2109
# Epoch 329: Train Loss: 0.0061, Val Loss: 0.0445, Train RMSE: 0.0783, Val RMSE: 0.2109
# Epoch 330: Train Loss: 0.0061, Val Loss: 0.0445, Train RMSE: 0.0783, Val RMSE: 0.2109
# Epoch 331: Train Loss: 0.0061, Val Loss: 0.0445, Train RMSE: 0.0782, Val RMSE: 0.2108
# Epoch 332: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0782, Val RMSE: 0.2108
# Epoch 333: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0781, Val RMSE: 0.2108
# Epoch 334: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0781, Val RMSE: 0.2108
# Epoch 335: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0780, Val RMSE: 0.2108
# Epoch 336: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0780, Val RMSE: 0.2107
# Epoch 337: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0780, Val RMSE: 0.2107
# Epoch 338: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0779, Val RMSE: 0.2107
# Epoch 339: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0779, Val RMSE: 0.2107
# Epoch 340: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0778, Val RMSE: 0.2107
# Epoch 341: Train Loss: 0.0061, Val Loss: 0.0444, Train RMSE: 0.0778, Val RMSE: 0.2107
# Epoch 342: Train Loss: 0.0060, Val Loss: 0.0444, Train RMSE: 0.0777, Val RMSE: 0.2107
# Epoch 343: Train Loss: 0.0060, Val Loss: 0.0444, Train RMSE: 0.0777, Val RMSE: 0.2106
# Epoch 344: Train Loss: 0.0060, Val Loss: 0.0444, Train RMSE: 0.0777, Val RMSE: 0.2106
# Epoch 345: Train Loss: 0.0060, Val Loss: 0.0444, Train RMSE: 0.0776, Val RMSE: 0.2106
# Epoch 346: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0776, Val RMSE: 0.2106
# Epoch 347: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0775, Val RMSE: 0.2106
# Epoch 348: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0775, Val RMSE: 0.2106
# Epoch 349: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0775, Val RMSE: 0.2105
# Epoch 350: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0774, Val RMSE: 0.2105
# Epoch 351: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0774, Val RMSE: 0.2105
# Epoch 352: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0773, Val RMSE: 0.2105
# Epoch 353: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0773, Val RMSE: 0.2105
# Epoch 354: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0773, Val RMSE: 0.2105
# Epoch 355: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0772, Val RMSE: 0.2105
# Epoch 356: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0772, Val RMSE: 0.2104
# Epoch 357: Train Loss: 0.0060, Val Loss: 0.0443, Train RMSE: 0.0772, Val RMSE: 0.2104
# Epoch 358: Train Loss: 0.0059, Val Loss: 0.0443, Train RMSE: 0.0771, Val RMSE: 0.2104
# Epoch 359: Train Loss: 0.0059, Val Loss: 0.0443, Train RMSE: 0.0771, Val RMSE: 0.2104
# Epoch 360: Train Loss: 0.0059, Val Loss: 0.0443, Train RMSE: 0.0770, Val RMSE: 0.2104
# Epoch 361: Train Loss: 0.0059, Val Loss: 0.0443, Train RMSE: 0.0770, Val RMSE: 0.2104
# Epoch 362: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0770, Val RMSE: 0.2103
# Epoch 363: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0769, Val RMSE: 0.2103
# Epoch 364: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0769, Val RMSE: 0.2103
# Epoch 365: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0769, Val RMSE: 0.2103
# Epoch 366: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0768, Val RMSE: 0.2103
# Epoch 367: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0768, Val RMSE: 0.2103
# Epoch 368: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0768, Val RMSE: 0.2103
# Epoch 369: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0767, Val RMSE: 0.2103
# Epoch 370: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0767, Val RMSE: 0.2102
# Epoch 371: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0767, Val RMSE: 0.2102
# Epoch 372: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0766, Val RMSE: 0.2102
# Epoch 373: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0766, Val RMSE: 0.2102
# Epoch 374: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0766, Val RMSE: 0.2102
# Epoch 375: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0765, Val RMSE: 0.2102
# Epoch 376: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0765, Val RMSE: 0.2102
# Epoch 377: Train Loss: 0.0059, Val Loss: 0.0442, Train RMSE: 0.0765, Val RMSE: 0.2102
# Epoch 378: Train Loss: 0.0058, Val Loss: 0.0442, Train RMSE: 0.0765, Val RMSE: 0.2101
# Epoch 379: Train Loss: 0.0058, Val Loss: 0.0442, Train RMSE: 0.0764, Val RMSE: 0.2101
# Epoch 380: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0764, Val RMSE: 0.2101
# Epoch 381: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0764, Val RMSE: 0.2101
# Epoch 382: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0763, Val RMSE: 0.2101
# Epoch 383: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0763, Val RMSE: 0.2101
# Epoch 384: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0763, Val RMSE: 0.2101
# Epoch 385: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0763, Val RMSE: 0.2101
# Epoch 386: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0762, Val RMSE: 0.2100
# Epoch 387: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0762, Val RMSE: 0.2100
# Epoch 388: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0762, Val RMSE: 0.2100
# Epoch 389: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0761, Val RMSE: 0.2100
# Epoch 390: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0761, Val RMSE: 0.2100
# Epoch 391: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0761, Val RMSE: 0.2100
# Epoch 392: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0761, Val RMSE: 0.2100
# Epoch 393: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0760, Val RMSE: 0.2100
# Epoch 394: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0760, Val RMSE: 0.2100
# Epoch 395: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0760, Val RMSE: 0.2099
# Epoch 396: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0760, Val RMSE: 0.2099
# Epoch 397: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0759, Val RMSE: 0.2099
# Epoch 398: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0759, Val RMSE: 0.2099
# Epoch 399: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0759, Val RMSE: 0.2099
# Epoch 400: Train Loss: 0.0058, Val Loss: 0.0441, Train RMSE: 0.0759, Val RMSE: 0.2099
# Epoch 401: Train Loss: 0.0058, Val Loss: 0.0440, Train RMSE: 0.0758, Val RMSE: 0.2099
# Epoch 402: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0758, Val RMSE: 0.2099
# Epoch 403: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0758, Val RMSE: 0.2099
# Epoch 404: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0758, Val RMSE: 0.2098
# Epoch 405: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0757, Val RMSE: 0.2098
# Epoch 406: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0757, Val RMSE: 0.2098
# Epoch 407: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0757, Val RMSE: 0.2098
# Epoch 408: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0757, Val RMSE: 0.2098
# Epoch 409: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0756, Val RMSE: 0.2098
# Epoch 410: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0756, Val RMSE: 0.2098
# Epoch 411: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0756, Val RMSE: 0.2098
# Epoch 412: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0756, Val RMSE: 0.2098
# Epoch 413: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0756, Val RMSE: 0.2098
# Epoch 414: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0755, Val RMSE: 0.2097
# Epoch 415: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0755, Val RMSE: 0.2097
# Epoch 416: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0755, Val RMSE: 0.2097
# Epoch 417: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0755, Val RMSE: 0.2097
# Epoch 418: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0754, Val RMSE: 0.2097
# Epoch 419: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0754, Val RMSE: 0.2097
# Epoch 420: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0754, Val RMSE: 0.2097
# Epoch 421: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0754, Val RMSE: 0.2097
# Epoch 422: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0754, Val RMSE: 0.2097
# Epoch 423: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0753, Val RMSE: 0.2097
# Epoch 424: Train Loss: 0.0057, Val Loss: 0.0440, Train RMSE: 0.0753, Val RMSE: 0.2096
# Epoch 425: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0753, Val RMSE: 0.2096
# Epoch 426: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0753, Val RMSE: 0.2096
# Epoch 427: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0753, Val RMSE: 0.2096
# Epoch 428: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0752, Val RMSE: 0.2096
# Epoch 429: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0752, Val RMSE: 0.2096
# Epoch 430: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0752, Val RMSE: 0.2096
# Epoch 431: Train Loss: 0.0057, Val Loss: 0.0439, Train RMSE: 0.0752, Val RMSE: 0.2096
# Epoch 432: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0752, Val RMSE: 0.2096
# Epoch 433: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0751, Val RMSE: 0.2096
# Epoch 434: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0751, Val RMSE: 0.2096
# Epoch 435: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0751, Val RMSE: 0.2096
# Epoch 436: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0751, Val RMSE: 0.2095
# Epoch 437: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0751, Val RMSE: 0.2095
# Epoch 438: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 439: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 440: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 441: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 442: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 443: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0750, Val RMSE: 0.2095
# Epoch 444: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 445: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 446: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 447: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 448: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 449: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0749, Val RMSE: 0.2095
# Epoch 450: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 451: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 452: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 453: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 454: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 455: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0748, Val RMSE: 0.2094
# Epoch 456: Train Loss: 0.0056, Val Loss: 0.0439, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 457: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 458: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 459: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 460: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 461: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0747, Val RMSE: 0.2094
# Epoch 462: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2094
# Epoch 463: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2094
# Epoch 464: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2094
# Epoch 465: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2094
# Epoch 466: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2093
# Epoch 467: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2093
# Epoch 468: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0746, Val RMSE: 0.2093
# Epoch 469: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 470: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 471: Train Loss: 0.0056, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 472: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 473: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 474: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 475: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0745, Val RMSE: 0.2093
# Epoch 476: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2093
# Epoch 477: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2093
# Epoch 478: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2093
# Epoch 479: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2093
# Epoch 480: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2093
# Epoch 481: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2092
# Epoch 482: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0744, Val RMSE: 0.2092
# Epoch 483: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 484: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 485: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 486: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 487: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 488: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0743, Val RMSE: 0.2092
# Epoch 489: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0742, Val RMSE: 0.2092
# Epoch 490: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0742, Val RMSE: 0.2092
# Epoch 491: Train Loss: 0.0055, Val Loss: 0.0438, Train RMSE: 0.0742, Val RMSE: 0.2092
# Epoch 492: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0742, Val RMSE: 0.2092
# Epoch 493: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0742, Val RMSE: 0.2092
# Epoch 494: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0742, Val RMSE: 0.2091
# Epoch 495: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0742, Val RMSE: 0.2091
# Epoch 496: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 497: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 498: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 499: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 500: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 501: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 502: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0741, Val RMSE: 0.2091
# Epoch 503: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 504: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 505: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 506: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 507: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 508: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 509: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0740, Val RMSE: 0.2091
# Epoch 510: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 511: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 512: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 513: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 514: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 515: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 516: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 517: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0739, Val RMSE: 0.2090
# Epoch 518: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 519: Train Loss: 0.0055, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 520: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 521: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 522: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 523: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 524: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 525: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0738, Val RMSE: 0.2090
# Epoch 526: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 527: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 528: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 529: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 530: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 531: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 532: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 533: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 534: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0737, Val RMSE: 0.2090
# Epoch 535: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2090
# Epoch 536: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2090
# Epoch 537: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2090
# Epoch 538: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2090
# Epoch 539: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2090
# Epoch 540: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2089
# Epoch 541: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2089
# Epoch 542: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2089
# Epoch 543: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2089
# Epoch 544: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0736, Val RMSE: 0.2089
# Epoch 545: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 546: Train Loss: 0.0054, Val Loss: 0.0437, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 547: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 548: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 549: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 550: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 551: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 552: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 553: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 554: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0735, Val RMSE: 0.2089
# Epoch 555: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 556: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 557: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 558: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 559: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 560: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 561: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 562: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 563: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 564: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 565: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0734, Val RMSE: 0.2089
# Epoch 566: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 567: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 568: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 569: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 570: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 571: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 572: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 573: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 574: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 575: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 576: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 577: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0733, Val RMSE: 0.2089
# Epoch 578: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 579: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 580: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 581: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 582: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 583: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 584: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 585: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 586: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 587: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 588: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 589: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0732, Val RMSE: 0.2089
# Epoch 590: Train Loss: 0.0054, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2089
# Epoch 591: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2089
# Epoch 592: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 593: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 594: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 595: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 596: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 597: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 598: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 599: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 600: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 601: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 602: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 603: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0731, Val RMSE: 0.2088
# Epoch 604: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 605: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 606: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 607: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 608: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 609: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 610: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 611: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 612: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 613: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 614: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 615: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 616: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0730, Val RMSE: 0.2088
# Epoch 617: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 618: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 619: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 620: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 621: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 622: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 623: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 624: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 625: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 626: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 627: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 628: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 629: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 630: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0729, Val RMSE: 0.2088
# Epoch 631: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 632: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 633: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 634: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 635: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 636: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 637: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 638: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 639: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 640: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 641: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 642: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 643: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 644: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 645: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 646: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0728, Val RMSE: 0.2088
# Epoch 647: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 648: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 649: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 650: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 651: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 652: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 653: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 654: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 655: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 656: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 657: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 658: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 659: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 660: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 661: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 662: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 663: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0727, Val RMSE: 0.2088
# Epoch 664: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2088
# Epoch 665: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2088
# Epoch 666: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2088
# Epoch 667: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2088
# Epoch 668: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 669: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 670: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 671: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 672: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 673: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 674: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 675: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 676: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 677: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 678: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 679: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 680: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 681: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 682: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0726, Val RMSE: 0.2087
# Epoch 683: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 684: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 685: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 686: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 687: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 688: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 689: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 690: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 691: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 692: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 693: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 694: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 695: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 696: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 697: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 698: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 699: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087
# Epoch 700: Train Loss: 0.0053, Val Loss: 0.0436, Train RMSE: 0.0725, Val RMSE: 0.2087

# %%
# Save the model
torch.save(model.state_dict(), 'gin_model_individualElephant.pt')

# %%
# Load and evaluate the model
from sklearn.metrics import mean_squared_error
model.load_state_dict(torch.load('gin_model_individualElephant.pt'))
model.eval()

def evaluate_model(test_loader, model):
    actuals = []
    predictions = []
    total_loss = 0
    criterion = torch.nn.MSELoss()  # Assuming MSE loss for evaluation
    with torch.no_grad():
        for data in test_loader:
            output = model(data)
            loss = criterion(output, data.y)
            total_loss += loss.item()
            actuals.append(data.y.cpu().numpy())
            predictions.append(output.cpu().numpy())
    actuals = np.vstack(actuals)
    predictions = np.vstack(predictions)
    avg_loss = total_loss / len(test_loader)
    rmse = np.sqrt(mean_squared_error(actuals, predictions))
    return actuals, predictions, avg_loss, rmse

# Evaluate the model
actuals, predictions, avg_loss, rmse = evaluate_model(val_loader, model)

def remove_outliers(data, z_threshold=3):
    mean = np.mean(data, axis=0)
    std_dev = np.std(data, axis=0)
    z_scores = (data - mean) / std_dev
    filtered_data = data[np.all(np.abs(z_scores) < z_threshold, axis=1)]
    return filtered_data

# Visualize Actual vs. Predicted Coordinates
def visualize_results_side_by_side(actuals, predictions):
    actuals_clean = remove_outliers(actuals)
    predictions_clean = remove_outliers(predictions)

    min_lat = min(actuals_clean[:, 0].min(), predictions_clean[:, 0].min())
    max_lat = max(actuals_clean[:, 0].max(), predictions_clean[:, 0].max())
    min_lon = min(actuals_clean[:, 1].min(), predictions_clean[:, 1].min())
    max_lon = max(actuals_clean[:, 1].max(), predictions_clean[:, 1].max())

    # Plot actual coordinates
    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(actuals_clean[:, 0], actuals_clean[:, 1], color='blue', alpha=0.5)
    plt.title('Actual Coordinates')
    plt.xlabel('Latitude')
    plt.ylabel('Longitude')
    plt.grid(True)
    plt.xlim(min_lat, max_lat)
    plt.ylim(min_lon, max_lon)

    # Plot predicted coordinates
    plt.subplot(1, 2, 2)
    plt.scatter(predictions_clean[:, 0], predictions_clean[:, 1], color='red', alpha=0.5)
    plt.title('Predicted Coordinates')
    plt.xlabel('Latitude')
    plt.ylabel('Longitude')
    plt.grid(True)
    plt.xlim(min_lat, max_lat)
    plt.ylim(min_lon, max_lon)

    plt.suptitle('Actual vs Predicted Coordinates')
    plt.show()

    print(f"Average Evaluation Loss: {avg_loss:.4f}")
    print(f"Root Mean Square Error (RMSE): {rmse:.4f}")

visualize_results_side_by_side(actuals, predictions)
# Out:
# Average Evaluation Loss: 0.0129
# Root Mean Square Error (RMSE): 0.1136

# %%
# !pip install geopandas contextily
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Collecting contextily
#   Downloading contextily-1.6.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (9.4.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 70.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily) (2024.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.1.2)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting snuggs>=1.4.1 (from rasterio->contextily)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.0.7)
# Installing collected packages: snuggs, mercantile, affine, rasterio, contextily
# Successfully installed affine-2.4.0 contextily-1.6.0 mercantile-1.2.1 rasterio-1.3.10 snuggs-1.4.7

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import geopandas as gpd
import contextily as ctx
from shapely.geometry import Point

# Load and evaluate the model
model.load_state_dict(torch.load('gin_model_individualElephant.pt'))
model.eval()

def evaluate_model(test_loader, model):
    actuals = []
    predictions = []
    total_loss = 0
    criterion = torch.nn.MSELoss()  # Assuming MSE loss for evaluation
    with torch.no_grad():
        for data in test_loader:
            output = model(data)
            loss = criterion(output, data.y)
            total_loss += loss.item()
            actuals.append(data.y.cpu().numpy())
            predictions.append(output.cpu().numpy())
    actuals = np.vstack(actuals)
    predictions = np.vstack(predictions)
    avg_loss = total_loss / len(test_loader)
    rmse = np.sqrt(mean_squared_error(actuals, predictions))
    return actuals, predictions, avg_loss, rmse

actuals, predictions, avg_loss, rmse = evaluate_model(val_loader, model)

def remove_outliers(data, z_threshold=3):
    mean = np.mean(data, axis=0)
    std_dev = np.std(data, axis=0)
    z_scores = (data - mean) / std_dev
    filtered_data = data[np.all(np.abs(z_scores) < z_threshold, axis=1)]
    return filtered_data

# Function to convert coordinates to GeoDataFrame
def to_geodataframe(coords, crs="EPSG:4326"):
    geometry = [Point(xy) for xy in zip(coords[:, 1], coords[:, 0])]
    return gpd.GeoDataFrame(geometry=geometry, crs=crs)

# Function to plot actual vs. predicted coordinates on a map
def plot_actual_vs_predicted_on_map(actuals, predictions):
    actuals_clean = remove_outliers(actuals)
    predictions_clean = remove_outliers(predictions)

    # Create GeoDataFrames
    gdf_actuals = to_geodataframe(actuals_clean)
    gdf_predictions = to_geodataframe(predictions_clean)

    # Convert GeoDataFrames to Web Mercator for contextily
    gdf_actuals = gdf_actuals.to_crs(epsg=3857)
    gdf_predictions = gdf_predictions.to_crs(epsg=3857)

    # Determine common axis limits
    min_lat = min(gdf_actuals.geometry.y.min(), gdf_predictions.geometry.y.min())
    max_lat = max(gdf_actuals.geometry.y.max(), gdf_predictions.geometry.y.max())
    min_lon = min(gdf_actuals.geometry.x.min(), gdf_predictions.geometry.x.min())
    max_lon = max(gdf_actuals.geometry.x.max(), gdf_predictions.geometry.x.max())

    # Plot side by side
    fig, axes = plt.subplots(1, 2, figsize=(20, 10))

    # Plot actual coordinates
    gdf_actuals.plot(ax=axes[0], marker='o', color='blue', alpha=0.5, label='Actual')
    ctx.add_basemap(axes[0], crs=gdf_actuals.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik)
    axes[0].set_title('Actual Coordinates')
    axes[0].set_xlabel('Longitude')
    axes[0].set_ylabel('Latitude')
    axes[0].set_xlim(min_lon, max_lon)
    axes[0].set_ylim(min_lat, max_lat)
    axes[0].legend()

    # Plot predicted coordinates
    gdf_predictions.plot(ax=axes[1], marker='o', color='red', alpha=0.5, label='Predicted')
    ctx.add_basemap(axes[1], crs=gdf_predictions.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik)
    axes[1].set_title('Predicted Coordinates')
    axes[1].set_xlabel('Longitude')
    axes[1].set_ylabel('Latitude')
    axes[1].set_xlim(min_lon, max_lon)
    axes[1].set_ylim(min_lat, max_lat)
    axes[1].legend()

    plt.suptitle('Actual vs Predicted Coordinates on Map')
    plt.tight_layout()
    plt.show()

# Call the function to plot
plot_actual_vs_predicted_on_map(actuals, predictions)
